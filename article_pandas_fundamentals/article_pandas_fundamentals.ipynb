# %% [markdown]
# # Code for pandas fundamentals (Spotify)

# %% [markdown]
# Dataset: Spotify Tracks Dataset
#
# From: https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load Dataset

# %%
spotify = pd.read_csv("spotify_tracks_dataset.csv", index_col=0)

# %% [markdown]
# ## 3. Group 1 - Exploring

# %%
# View the first 5 rows
spotify.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %%
# View the first 10 rows
spotify.head(10)
# Out:
#                  track_id                               artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# ...

# %%
# Get overview of the dataset
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114000 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          114000 non-null  object
#  1   artists           113999 non-null  object
#  2   album_name        113999 non-null  object
#  3   track_name        113999 non-null  object
#  4   popularity        114000 non-null  int64
#  5   duration_ms       114000 non-null  int64
#  6   explicit          114000 non-null  bool
#  7   danceability      114000 non-null  float64
#  8   energy            114000 non-null  float64
#  9   key               114000 non-null  int64
#  10  loudness          114000 non-null  float64
#  11  mode              114000 non-null  int64
#  12  speechiness       114000 non-null  float64
#  13  acousticness      114000 non-null  float64
#  14  instrumentalness  114000 non-null  float64
#  15  liveness          114000 non-null  float64
# ...

# %%
# Get summary stats
spotify.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
# Get summary stats for all variable types
spotify.describe(include="all")
# Out:
#                       track_id      artists                  album_name  \
# count                   114000       113999                      113999
# unique                   89741        31437                       46589
# top     6S3JlDAGk3uu3NtZbPnuhS  The Beatles  Alternative Christmas 2022
# freq                         9          279                         195
# mean                       NaN          NaN                         NaN
# std                        NaN          NaN                         NaN
# min                        NaN          NaN                         NaN
# 25%                        NaN          NaN                         NaN
# 50%                        NaN          NaN                         NaN
# 75%                        NaN          NaN                         NaN
# max                        NaN          NaN                         NaN
#
#              track_name     popularity   duration_ms explicit   danceability  \
# ...

# %%
# See the dimensions of the dataset
spotify.shape
# Out:
# (114000, 20)

# %% [markdown]
# ## 4. Group 2- Selecting & Filtering

# %%
# Selectin data from a column
spotify["track_name"]
# Out:
# 0                             Comedy
# 1                   Ghost - Acoustic
# 2                     To Begin Again
# 3         Can't Help Falling In Love
# 4                            Hold On
#                      ...
# 113995           Sleep My Little Boy
# 113996              Water Into Light
# 113997                Miss Perfumado
# 113998                       Friends
# 113999                     Barbincor
# Name: track_name, Length: 114000, dtype: object

# %%
# Selecting data from multiple columns
spotify[["track_name", "popularity"]]
# Out:
#                         track_name  popularity
# 0                           Comedy          73
# 1                 Ghost - Acoustic          55
# 2                   To Begin Again          57
# 3       Can't Help Falling In Love          71
# 4                          Hold On          82
# ...                            ...         ...
# 113995         Sleep My Little Boy          21
# 113996            Water Into Light          22
# 113997              Miss Perfumado          22
# 113998                     Friends          41
# 113999                   Barbincor          22
#
# [114000 rows x 2 columns]

# %%
# Select records where popularity is greater than 80
spotify[spotify["popularity"] > 80]
# Out:
#                       track_id                   artists  \
# 4       5vjLSffimiIP26QG5WcN2K          Chord Overstreet
# 2000    5E30LdtzQTGqRvNd7l6kG5         The Neighbourhood
# 2001    2Y0iGXY6m6immVb2ktbseM                      MGMT
# 2002    2K7xn816oNHJZ0aVqdQsha         The Neighbourhood
# 2003    2QjOHCTQ1Jl3zawyYOpxh6         The Neighbourhood
# ...                        ...                       ...
# 109000  2vXKRlJBXyOcvZYTdNeckS  Gesaffelstein;The Weeknd
# 110000  6f3Slt0GbA2bPZlz0aIFXN                    Tiësto
# 110004  0bI7K9Becu2dtXK1Q3cZNB            Tiësto;KAROL G
# 110005  18asYwWugKjjsihZ0YvRxO            Tiësto;Ava Max
# 110006  3Z7CaxQkqbIs1rewKi6v4W         Tiësto;Charli XCX
#
#                                              album_name  \
# 4                                               Hold On
# 2000                                         Wiped Out!
# 2001                                    Little Dark Age
# ...

# %%
# Select records where popularity is greater than 80 from The Neighbourhood
spotify[(spotify["popularity"] > 80) & (spotify["artists"] == "The Neighbourhood")]
# Out:
#                      track_id            artists  \
# 2000   5E30LdtzQTGqRvNd7l6kG5  The Neighbourhood
# 2002   2K7xn816oNHJZ0aVqdQsha  The Neighbourhood
# 2003   2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 2004   7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 3000   5E30LdtzQTGqRvNd7l6kG5  The Neighbourhood
# 3002   2K7xn816oNHJZ0aVqdQsha  The Neighbourhood
# 3003   2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 3100   7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 81853  2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 91002  2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 91100  5E30LdtzQTGqRvNd7l6kG5  The Neighbourhood
# 91105  2K7xn816oNHJZ0aVqdQsha  The Neighbourhood
# 91401  7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
#
#                                             album_name          track_name  \
# 2000                                        Wiped Out!        Daddy Issues
# 2002   Hard To Imagine The Neighbourhood Ever Changing            Softcore
# ...

# %%
# Filter the same data with .query()
spotify.query("popularity > 80 and artists == 'The Neighbourhood'")
# Out:
#                      track_id            artists  \
# 2000   5E30LdtzQTGqRvNd7l6kG5  The Neighbourhood
# 2002   2K7xn816oNHJZ0aVqdQsha  The Neighbourhood
# 2003   2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 2004   7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 3000   5E30LdtzQTGqRvNd7l6kG5  The Neighbourhood
# 3002   2K7xn816oNHJZ0aVqdQsha  The Neighbourhood
# 3003   2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 3100   7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
# 81853  2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 91002  2QjOHCTQ1Jl3zawyYOpxh6  The Neighbourhood
# 91100  5E30LdtzQTGqRvNd7l6kG5  The Neighbourhood
# 91105  2K7xn816oNHJZ0aVqdQsha  The Neighbourhood
# 91401  7zwn1eykZtZ5LODrf7c0tS  The Neighbourhood
#
#                                             album_name          track_name  \
# 2000                                        Wiped Out!        Daddy Issues
# 2002   Hard To Imagine The Neighbourhood Ever Changing            Softcore
# ...

# %% [markdown]
# ## 5. Group 3 - Sorting

# %%
# Sort tracks by 'popularity' in descending order
spotify.sort_values(by='popularity', ascending=False)
# Out:
#                      track_id                       artists  \
# 81051  3nqQXoyQOWXiESFLlDF1hG          Sam Smith;Kim Petras
# 20001  3nqQXoyQOWXiESFLlDF1hG          Sam Smith;Kim Petras
# 51664  2tTmW7RDtMQtBk7m2rYeSw              Bizarrap;Quevedo
# 89411  5ww2BF9slyYgNOk37BlC4u                 Manuel Turizo
# 30003  4uUG5RXrOk84mYEfFvj3cK       David Guetta;Bebe Rexha
# ...                       ...                           ...
# 25065  1uQo8gIQWJGrY6wZLReyUP  Eric Prydz;Empire of the Sun
# 25047  41aKdU4Eqr2aYFbSPT6GeS                  Donna Summer
# 25046  0Ant6wBzTsOcH63OgzmaXU                 Lionel Richie
# 25045  3tgVp3M5fgSNhEUE1iMILQ                      Bee Gees
# 25079  5jGQrDqkxAnsBcZJfvaQg0                    Rick James
#
#                                   album_name  \
# 81051              Unholy (feat. Kim Petras)
# 20001              Unholy (feat. Kim Petras)
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52
# 89411                             La Bachata
# ...
